Сельдерей пахучий
трава, корни
май, июнь, июль, август
3
Смородина черная
листья, плоды
июнь, июль, август
2
Спорыш
трава
май, июнь, июль, август
2
Сушеница болотная
трава
июнь, июль, август
2
Тимьян ползучий или чабрец ползучий
трава
июнь, июль
3
Толокнянка обыкновенная
листья
апрель, май, июнь, июль
5
Тмин обыкновенный
плоды
июнь, июль
3
Тысячелистник обыкновенный
трава
июнь, июль, август, сентябрь
2
Укроп огородный
трава
май, июнь, июль
2
Фиалка трехцветная
трава
май, июнь
2
Цмин песчаный или бессмертник песчаный
соцветия
июнь, июль
3
Хвощ полевой
трава
июнь, июль, август
2
Хрен обыкновенный
корни
июль, август
3
Череда трехраздельная
трава
июнь, июль, август
2
Черника обыкновенная
листья, плоды
май, июнь, июль, август
3
Черемуха обыкновенная
плоды
август
5
Чистотел большой
трава
май, июнь, июль
2
Шалфей лекарственный
листья
июнь, июль
2
Шиповник коричный
плоды
сентябрь, октябрь
2
"""

# %%
k = 0
d = {'Plant Name' : [],
     'Вид сырья': [],
     'Календарь сбора, мес.' : [],
     'Максимальный срок хранения, год'  : []}

for i in table.split('\n')[1:-1]:
    if k % 4 == 0:
        d['Plant Name'].append(i)
    elif k % 4 == 1:
        d['Вид сырья'].append(i)
    elif k % 4 == 2:
        d['Календарь сбора, мес.'].append(i)
    else:
        d['Максимальный срок хранения, год'].append(i)
    k +=1

# %%
data = pd.DataFrame(d)

# %%
plants_base = pd.DataFrame({'Plant Name' : ['Аденостилес ромболистный',
 'Аир обыкновенный',
 'Алоэ древовидное ',
 'Алтей лекарственный  ',
 'Амми большая',
 'Амми зубная  ',
 'Анис обыкновенный',
 'Аралия высокая  ',
 'Арника горная  ',
 'Арника шамиссо  ',
 'Арония черноплодная  ',
 'Астрагал шерстистоцветковый',
 'Багульник болотный ',
 'Бадан толстолистный',
 'Баранец обыкновенный ',
 'Барбарис обыкновенный',
 'Барвинок малый',
 'Бархат амурский   ',
 'Бедренец камнеломка  ',
 'Безвременник великолепный',
 'Белена черная',
 'Белокопытник гибридный  ',
 'Берёза повислая  ',
 'Бессмертник песчаный  ',
 'Борец северный',
 'Боярышник кровавокрасный',
 'Бриофиллум перистый  ',
 'Брусника обыкновенная',
 'Бузина черная',
 'Валериана лекарственная',
 'Василек благословенный',
 'Василек посевной  ',
 'Вахта трехлистная   ',
 'Вербена лекарственная',
 'Вздутоплодник сибирский ',
 'Виноград культурный',
 'Водосбор обыкновенный',
 'Володушка золотистая',
 'Гамамелис виргинский',
 'Гармала обыкновенная  ',
 'Горец змеиный    ',
 'Горец перечный  ',
 'Горец почечуйный    ',
 'Горец птичий    ',
 'Горечавка жёлтая',
 'Горицвет весенний    ',
 'Горчица сарептская  ',
 'Гречиха съедобная  ',
 'Грыжник гладкий',
 'Девясил высокий',
 'Десмодиум канадский',
 'Диоскорея ниппонская  ',
 'Донник лекарственный  ',
 'Дуб обыкновенный  ',
 'Дурман индейский  ',
 'Дурман обыкновенный  ',
 'Дурнишник обыкновенный  ',
 'Душица обыкновенная ',
 'Дудник лекарственный  ',
 'Ель обыкновенная  ',
 'Желтушник раскидистый  ',
 'Женьшень  ',
 'Жостер слабительный  ',
 'Заманиха высокая',
 'Зверобой продырявленный',
 'Земляника лесная',
 'Змееголовник молдавский  ',
 'Золотарник канадский',
 'Золототысячник обыкновенный',
 'Зюзник европейский',
 'Истод тонколистный',
 'Калина обыкновенная',
 'Катарантус розовый  ',
 'Конский каштан обыкновенный',
 'Копеечник альпийский',
 'Копытень европейский',
 'Кориандр посевной  ',
 'Коровяк густоцветковый',
 'Крапива двудомная',
 'Красавка обыкновенная',
 'Кровохлёбка лекарственная',
 'Крушина ольховидная  ',
 'Кубышка жёлтая   ',
 'Кукуруза обыкновенная ',
 'Лабазник вязолистный  ',
 'Лабазник обыкновенный  ',
 'Ламинария японская    ',
 'Ландыш кейске  ',
 'Ландыш майский',
 'Лапчатка белая',
 'Лапчатка прямостоячая',
 'Лапчатка серебристая',
 'Лён посевой  ',
 'Леспедеца двуцветная',
 'Леспедеца копеечниковая  ',
 'Лимонник китайский',
 'Липа сердцевидная  ',
 'Ломонос виноградолистный',
 'Лопух большой ',
 'Магнолия крупноцветковая',
 'Маклея сердцевидная',
 'Малина обыкновенная',
 'Марена красильная    ',
 'Матьимачеха обыкновенная',
 'Мачок жёлтый',
 'Мелисса лекарственная  ',
 'Миндаль обыкновенный',
 'Можжевельник обыкновенный',
 'Морковь дикая',
 'Мята перечная    ',
 'Наперстянка крупноцветковая',
 'Ноготки лекарственные  ',
 'Облепиха крушиновидная  ',
 'Овес посевной',
 'Одуванчик изогнутый  ',
 'Окопник жёсткий',
 'Ольха чёрная  ',
 'Омела белая',
 'Ортосифон остистый ',
 'Очиток большой',
 'Пажитник сенной  ',
 'Паслен сладкогорький    ',
 'Пассифлора инкарнатная',
 'Пастернак посевной',
 'Пастушья сумка обыкновенная  ',
 'Переступень белый  ',
 'Перец однолетний',
 'Пижма обыкновенная',
 'Пион уклоняющийся  ',
 'Пиретрум цинерариелистный',
 'Плаун булавовидный',
 'Подорожник блошный   ',
 'Подорожник большой  ',
 'Подофилл щитовидный',
 'Полынь горькая',
 'Полынь обыкновенная ',
 'Прутняк обыкновенный',
 'Пустырник сердечный',
 'Рапонтикум сафлоровидный',
 'Расторопша пятнистая',
 'Ревень пальчатый тангутский',
 'Репешок волосистый  ',
 'Репешок обыкновенный',
 'Родиола розовая    ',
 'Ромашка аптечная  ',
 'Ромашка безъязычковая  ',
 'Рябина обыкновенная',
 'Сабельник болотный',
 'Свободноягодник колючий  ',
 'Секуринега полукустарниковая',
 'Серпуха венценосная',
 'Синюха голубая  ',
 'Скополия карниолийская  ',
 'Скумпия кожевенная',
 'Смоковница обыкновенная',
 'Смородина черная',
 'Солодка голая     ',
 'Софора японская',
 'Спорынья пурпуровая',
 'Стальник колючий  ',
 'Сумах дубильный',
 'Сушеница топяная  ',
 'Термопсис ланцетовидный',
 'Тимьян обыкновенный',
 'Тимьян ползучий   ',
 'Тмин обыкновенный',
 'Толокнянка обыкновенная',
 'Тыква обыкновенная',
 'Тысячелистник обыкновенный',
 'Укроп пахучий    ',
 'Фасоль обыкновенная',
 'Фенхель обыкновенный',
 'Ферула вонючая',
 'Фиалка трёхцветная  ',
 'Хвощ полевой    ',
 'Хмель обыкновенный  ',
 'Цетрария исландская  ',
 'Цикорий обыкновенный',
 'Чага    ',
 'Чемерица лобеля  ',
 'Череда трёхраздельная  ',
 'Черёмуха обыкновенная',
 'Черника обыкновенная',
 'Чернушка дамасская  ',
 'Чистотел большой  ',
 'Шалфей лекарственный  ',
 'Шиповник майский    ',
 'Шлемник байкальский',
 'Щавель конский  ',
 'Щитовник мужской  ',
 'Эвкалипт прутовидный',
 'Эвкоммия вязолистная',
 'Эрва шерстистая ',
 'Эфедра хвощевая    ',
 'Эхинацея пурпурная',
 'Якорцы стелющиеся']})

plants_base['Plant Name'] = plants_base['Plant Name'].apply(lambda x : x.strip())

# %%
plants_base = plants_base.merge(data, on=['Plant Name'], how='left')
plants_base['Plant Name'] = plants_base['Plant Name'].apply(lambda x : x.lower())
plants_base.index = plants_base['Plant Name']
plants_base = plants_base.fillna('')

# %%
dict_for_json = plants_base[plants_base.columns[1:]].to_dict('index')
for k, v in dict_for_json.items():
    for k1, v1 in v.items():
        if len(dict_for_json[k][k1]) == 0:
            dict_for_json[k][k1] = []
            continue
        dict_for_json[k][k1] = [i.strip() for i in v1.split(', ')]

# %%
with open('calendar_feats.json', 'w', encoding='utf8') as f:
    json.dump(dict_for_json, f, ensure_ascii=False, indent=4)

# %%
dict_for_json
# Out:
# {'аденостилес ромболистный': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'аир обыкновенный': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'алоэ древовидное': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'алтей лекарственный': {'Вид сырья': ['корни'],
#   'Календарь сбора, мес.': ['апрель', 'май', 'сентябрь', 'октябрь'],
#   'Максимальный срок хранения, год': ['3']},
#  'амми большая': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'амми зубная': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'анис обыкновенный': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
#  'аралия высокая': {'Вид сырья': [],
#   'Календарь сбора, мес.': [],
#   'Максимальный срок хранения, год': []},
# ...
